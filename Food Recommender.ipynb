# %% [markdown]
# ## Food Recommender

# %% [markdown]
# #### Importing Libraies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Datasets

# %% [markdown]
# #### 1st Dataset

# %%
nutritions = pd.read_csv('nutritions.csv', usecols=['Food Name','Category Name', 'Zinc', 'Vitamin B1', 'Vitamin B12',
       'Vitamin B2', 'Vitamin B3', 'Vitamin B5', 'Vitamin B6', 'Vitamin A (IU)', 'Vitamin D','Vitamin A RAE', 'Iron', 'Vitamin C'])
nutritions.head(3)
# Out:
#   Food Name Category Name     Iron  Vitamin A (IU)  Vitamin A RAE  Vitamin B1  \
# 0   Acerola        Fruits  0.00020           767.0       0.000038     0.00002
# 1     Apple        Fruits  0.00012            54.0       0.000003     0.00002
# 2   Apricot        Fruits  0.00039          1279.0       0.000096     0.00003
#
#    Vitamin B12  Vitamin B2  Vitamin B3  Vitamin B5  Vitamin B6  Vitamin C  \
# 0          0.0     0.00006     0.00040     0.00031     0.00001     1.6780
# 1          0.0     0.00003     0.00009     0.00006     0.00004     0.0046
# 2          0.0     0.00004     0.00060     0.00024     0.00005     0.0100
#
#       Zinc  Vitamin D
# 0  0.00010        NaN
# 1  0.00004        0.0
# 2  0.00020        0.0

# %%
nutritions['Vitamin A'] = nutritions['Vitamin A (IU)'] + nutritions['Vitamin A RAE']

# %%
nutritions['Vitamin B'] = nutritions['Vitamin B1']+nutritions['Vitamin B2']+nutritions['Vitamin B3']+nutritions['Vitamin B12']+nutritions['Vitamin B5']+nutritions['Vitamin B6']

# %% [markdown]
# ### Dataset1 Cleaning

# %% [markdown]
# #### Duplicates Removal

# %%
nutritions.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Drop Unwanted Cols

# %%
nutritions.drop(columns=['Vitamin A (IU)', 'Vitamin A RAE', 'Vitamin B1', 'Vitamin B12', 'Vitamin B2', 'Vitamin B3', 'Vitamin B5', 'Vitamin B6'], inplace=True)

# %% [markdown]
# #### Columns Information

# %%
nutritions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Food Name      1174 non-null   object
#  1   Category Name  1174 non-null   object
#  2   Iron           1153 non-null   float64
#  3   Vitamin C      1124 non-null   float64
#  4   Zinc           1108 non-null   float64
#  5   Vitamin D      829 non-null    float64
#  6   Vitamin A      1055 non-null   float64
#  7   Vitamin B      949 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 73.5+ KB

# %% [markdown]
# ### Dataset1 Statistics

# %%
nutritions.describe()
# Out:
#               Iron    Vitamin C         Zinc     Vitamin D      Vitamin A  \
# count  1153.000000  1124.000000  1108.000000  8.290000e+02    1055.000000
# mean      0.002870     0.010601     0.001500  7.752714e-07     990.181178
# std       0.007132     0.055625     0.003209  8.890438e-06    4620.797616
# min       0.000000     0.000000     0.000000  0.000000e+00       0.000000
# 25%       0.000380     0.000000     0.000220  0.000000e+00       0.000000
# 50%       0.001000     0.000500     0.000640  0.000000e+00      50.000015
# 75%       0.002500     0.006300     0.001600  0.000000e+00     360.000048
# max       0.124000     1.678000     0.079000  2.500000e-04  100000.030000
#
#         Vitamin B
# count  949.000000
# mean     0.004572
# std      0.013204
# min      0.000000
# 25%      0.000800
# 50%      0.001910
# 75%      0.004832
# max      0.161970

# %%
nutritions[['Iron', 'Vitamin A','Vitamin B', 'Vitamin C', 'Zinc', 'Vitamin D']].corr()
# Out:
#                Iron  Vitamin A  Vitamin B  Vitamin C      Zinc  Vitamin D
# Iron       1.000000   0.133164   0.201854   0.047527  0.325492  -0.000573
# Vitamin A  0.133164   1.000000   0.067172   0.046547  0.031041   0.656369
# Vitamin B  0.201854   0.067172   1.000000  -0.014468  0.150544   0.114969
# Vitamin C  0.047527   0.046547  -0.014468   1.000000 -0.021086  -0.022014
# Zinc       0.325492   0.031041   0.150544  -0.021086  1.000000   0.007069
# Vitamin D -0.000573   0.656369   0.114969  -0.022014  0.007069   1.000000

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer

ct = ColumnTransformer(transformers=[('scaler',MinMaxScaler(),['Iron', 'Vitamin A', 'Vitamin B', 'Vitamin C', 'Zinc', 'Vitamin D'])],
                       remainder='passthrough',sparse_threshold=0)

nutritions = pd.DataFrame(ct.fit_transform(nutritions))
nutritions.rename(columns={0:'Iron', 1:'Vitamin A', 2:'Vitamin B', 3:'Vitamin C', 4:'Zinc', 5:'Vitamin D', 6:'Food', 7:'Category'}, inplace=True)

# %%
nutritions.sort_values(by='Iron',ascending=False,ignore_index=True).loc[:9,['Food','Category']]
# Out:
#                 Food    Category
# 0        Dried thyme      Spices
# 1           Marjoram      Spices
# 2              Cumin      Spices
# 3           Turmeric      Spices
# 4    Dried dill weed      Spices
# 5          Baby food  Baby Foods
# 6           Bay leaf      Spices
# 7         Star anise      Spices
# 8            Oregano      Spices
# 9  Poultry seasoning      Spices

# %%
nutritions.sort_values(by='Vitamin A',ascending=False,ignore_index=True).loc[:9,['Food','Category']]
# Out:
#                  Food                         Category
# 0       Cod liver oil                          Seafood
# 1             Paprika                           Spices
# 2      Cayenne pepper                           Spices
# 3     Pasilla peppers                       Vegetables
# 4          Beef Liver                             Meat
# 5  Chili powder spice                           Spices
# 6        Grape leaves                           Greens
# 7  Sweet potato chips  Meals, Entrees, and Side Dishes
# 8             Poblano                       Vegetables
# 9        Sweet potato                       Vegetables

# %%
nutritions.sort_values(by='Vitamin B',ascending=False,ignore_index=True).loc[:9,['Food','Category']]
# Out:
#                               Food                         Category
# 0                        Candy bar                           Sweets
# 1                       Mortadella                             Meat
# 2                              Pea                       Vegetables
# 3                         Powerade                        Beverages
# 4                   Pineapple cake                   Baked Products
# 5                    Blueberry pie                   Baked Products
# 6                            Yeast                   Baked Products
# 7                        Baby food                       Baby Foods
# 8  Kellogg's Frosted Flakes Cereal  Meals, Entrees, and Side Dishes
# 9                      Bran cereal  Meals, Entrees, and Side Dishes

# %%
nutritions.sort_values(by='Vitamin C',ascending=False,ignore_index=True).loc[:9,['Food','Category']]
# Out:
#              Food    Category
# 0         Acerola      Fruits
# 1        Rose hip      Fruits
# 2    Chili Pepper  Vegetables
# 3           Guava      Fruits
# 4           Thyme      Greens
# 5      Cloudberry      Fruits
# 6    Chili pepper  Vegetables
# 7  Drumstick tree      Greens
# 8         Parsley      Greens
# 9   Dried parsely      Spices

# %%
nutritions.sort_values(by='Vitamin D',ascending=False,ignore_index=True).loc[:9,['Food','Category']]
# Out:
#                 Food         Category
# 0      Cod liver oil          Seafood
# 1  Maitake mushrooms        Mushrooms
# 2              Trout          Seafood
# 3          Swordfish          Seafood
# 4     Sockeye salmon          Seafood
# 5      Smoked salmon          Seafood
# 6    Steelhead trout          Seafood
# 7           Sturgeon          Seafood
# 8             Salmon          Seafood
# 9           Fish oil  Oils and Sauces

# %%
nutritions.sort_values(by='Zinc',ascending=False,ignore_index=True).loc[:9,['Food','Category']]
# Out:
#                                   Food                         Category
# 0                              Oysters                          Seafood
# 1                  Lucky Charms Cereal  Meals, Entrees, and Side Dishes
# 2  General Mills Cinnamon Toast Crunch  Meals, Entrees, and Side Dishes
# 3                           Kix Cereal  Meals, Entrees, and Side Dishes
# 4               General Mills Cheerios  Meals, Entrees, and Side Dishes
# 5                  Cap'n Crunch Cereal  Meals, Entrees, and Side Dishes
# 6            General Mills Cocoa Puffs  Meals, Entrees, and Side Dishes
# 7          General Mills Count Chocula  Meals, Entrees, and Side Dishes
# 8            General Mills Trix Cereal  Meals, Entrees, and Side Dishes
# 9                  Cookie Crisp Cereal  Meals, Entrees, and Side Dishes

# %% [markdown]
# #### 2nd Dataset

# %%
deficiency = pd.read_csv('deficiency.csv')
deficiency.head()
# Out:
#    Age  Gender       Diet Type Living Environment  Night Blindness  Dry Eyes  \
# 0   62    Male  Non-Vegetarian              Rural                1         0
# 1   52    Male      Vegetarian              Urban                0         0
# 2   53  Female      Vegetarian              Rural                0         0
# 3   40    Male  Non-Vegetarian              Rural                0         0
# 4   17  Female  Non-Vegetarian              Urban                0         0
#
#    Bleeding Gums  Fatigue  Tingling Sensation  Low Sun Exposure  \
# 0              0        0                   1                 1
# 1              0        0                   0                 1
# 2              0        1                   0                 0
# 3              0        0                   0                 0
# 4              0        1                   1                 0
#
#    Reduced Memory Capacity  Shortness of Breath  Loss of Appetite  \
# 0                        0                    0                 0
# 1                        0                    0                 0
# 2                        0                    0                 0
# 3                        1                    1                 0
# 4                        0                    0                 1
#
#    Fast Heart Rate  Brittle Nails  Weight Loss  \
# 0                0              0            1
# 1                0              0            1
# 2                0              0            0
# 3                1              0            0
# 4                1              0            0
#
#    Reduced Wound Healing Capacity    Skin Condition Predicted Deficiency
# 0                               1            Normal                 Zinc
# 1                               1            Normal          Vitamin B12
# 2                               0            Normal            Vitamin A
# 3                               0  Pale/Yellow Skin        No Deficiency
# 4                               0            Normal            Vitamin D

# %% [markdown]
# ## Dataset Cleaning

# %% [markdown]
# #### Duplicates Removal

# %%
deficiency.duplicated().sum()
# Out:
# 1

# %%
deficiency.drop_duplicates(inplace=True)

# %% [markdown]
# #### Drop Unwanted Cols

# %%
deficiency.reset_index(inplace=True)
deficiency.drop(columns=['index'], inplace=True)

# %% [markdown]
# ## Column Information

# %%
deficiency.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             999 non-null    int64
#  1   Gender                          999 non-null    object
#  2   Diet Type                       999 non-null    object
#  3   Living Environment              999 non-null    object
#  4   Night Blindness                 999 non-null    int64
#  5   Dry Eyes                        999 non-null    int64
#  6   Bleeding Gums                   999 non-null    int64
#  7   Fatigue                         999 non-null    int64
#  8   Tingling Sensation              999 non-null    int64
#  9   Low Sun Exposure                999 non-null    int64
#  10  Reduced Memory Capacity         999 non-null    int64
#  11  Shortness of Breath             999 non-null    int64
#  12  Loss of Appetite                999 non-null    int64
#  13  Fast Heart Rate                 999 non-null    int64
#  14  Brittle Nails                   999 non-null    int64
#  15  Weight Loss                     999 non-null    int64
#  16  Reduced Wound Healing Capacity  999 non-null    int64
#  17  Skin Condition                  999 non-null    object
#  18  Predicted Deficiency            999 non-null    object
# dtypes: int64(14), object(5)
# memory usage: 148.4+ KB

# %% [markdown]
# #### Drop Duplicates

# %%
# deficiency.duplicated().sum()

# %%
# deficiency.drop_duplicates(inplace=True)
# deficiency.reset_index(inplace=True)

# %% [markdown]
# ## Statistics

# %%
deficiency.describe()
# Out:
#               Age  Night Blindness    Dry Eyes  Bleeding Gums     Fatigue  \
# count  999.000000       999.000000  999.000000     999.000000  999.000000
# mean    39.692693         0.100100    0.160160       0.127127    0.419419
# std     16.969874         0.300284    0.366938       0.333282    0.493711
# min     10.000000         0.000000    0.000000       0.000000    0.000000
# 25%     25.000000         0.000000    0.000000       0.000000    0.000000
# 50%     39.000000         0.000000    0.000000       0.000000    0.000000
# 75%     54.000000         0.000000    0.000000       0.000000    1.000000
# max     69.000000         1.000000    1.000000       1.000000    1.000000
#
#        Tingling Sensation  Low Sun Exposure  Reduced Memory Capacity  \
# count          999.000000        999.000000               999.000000
# mean             0.155155          0.310310                 0.151151
# std              0.362234          0.462852                 0.358376
# min              0.000000          0.000000                 0.000000
# 25%              0.000000          0.000000                 0.000000
# 50%              0.000000          0.000000                 0.000000
# 75%              0.000000          1.000000                 0.000000
# max              1.000000          1.000000                 1.000000
#
#        Shortness of Breath  Loss of Appetite  Fast Heart Rate  Brittle Nails  \
# count           999.000000        999.000000       999.000000     999.000000
# mean              0.176176          0.146146         0.184184       0.142142
# std               0.381161          0.353430         0.387828       0.349371
# min               0.000000          0.000000         0.000000       0.000000
# 25%               0.000000          0.000000         0.000000       0.000000
# 50%               0.000000          0.000000         0.000000       0.000000
# 75%               0.000000          0.000000         0.000000       0.000000
# max               1.000000          1.000000         1.000000       1.000000
#
#        Weight Loss  Reduced Wound Healing Capacity
# count   999.000000                      999.000000
# mean      0.108108                        0.324324
# std       0.310672                        0.468356
# min       0.000000                        0.000000
# 25%       0.000000                        0.000000
# 50%       0.000000                        0.000000
# 75%       0.000000                        1.000000
# max       1.000000                        1.000000

# %%
deficiency[['Age','Night Blindness','Dry Eyes', 'Bleeding Gums', 'Fatigue', 'Tingling Sensation','Low Sun Exposure',
        'Reduced Memory Capacity', 'Shortness of Breath', 'Loss of Appetite', 'Fast Heart Rate', 'Brittle Nails', 'Weight Loss',
       'Reduced Wound Healing Capacity']].corr()
# Out:
#                                      Age  Night Blindness  Dry Eyes  \
# Age                             1.000000        -0.019716 -0.032478
# Night Blindness                -0.019716         1.000000 -0.018333
# Dry Eyes                       -0.032478        -0.018333  1.000000
# Bleeding Gums                  -0.036491        -0.017148 -0.060142
# Fatigue                        -0.016652        -0.019884  0.016001
# Tingling Sensation              0.036942         0.022887  0.023936
# Low Sun Exposure               -0.005962        -0.043480 -0.033332
# Reduced Memory Capacity        -0.034039        -0.029005 -0.024263
# Shortness of Breath             0.023250         0.003348 -0.037169
# Loss of Appetite                0.013343        -0.043568  0.020217
# Fast Heart Rate                 0.016526        -0.020808  0.010777
# Brittle Nails                  -0.006484        -0.021148 -0.013621
# Weight Loss                    -0.018400         0.055736 -0.020193
# Reduced Wound Healing Capacity  0.000324        -0.045829  0.012291
#
#                                 Bleeding Gums   Fatigue  Tingling Sensation  \
# Age                                 -0.036491 -0.016652            0.036942
# Night Blindness                     -0.017148 -0.019884            0.022887
# Dry Eyes                            -0.060142  0.016001            0.023936
# Bleeding Gums                        1.000000 -0.050338            0.019051
# Fatigue                             -0.050338  1.000000            0.022355
# Tingling Sensation                   0.019051  0.022355            1.000000
# Low Sun Exposure                     0.003836  0.048145           -0.024492
# Reduced Memory Capacity              0.023522 -0.030198           -0.041900
# Shortness of Breath                 -0.042391  0.043567           -0.002230
# Loss of Appetite                    -0.004768  0.073300           -0.005108
# Fast Heart Rate                     -0.018538  0.025259            0.010352
# Brittle Nails                        0.008157 -0.072948           -0.016089
# Weight Loss                          0.051002 -0.034606           -0.006738
# Reduced Wound Healing Capacity      -0.039730 -0.025531            0.039747
#
#                                 Low Sun Exposure  Reduced Memory Capacity  \
# Age                                    -0.005962                -0.034039
# Night Blindness                        -0.043480                -0.029005
# Dry Eyes                               -0.033332                -0.024263
# Bleeding Gums                           0.003836                 0.023522
# Fatigue                                 0.048145                -0.030198
# Tingling Sensation                     -0.024492                -0.041900
# Low Sun Exposure                        1.000000                 0.025028
# Reduced Memory Capacity                 0.025028                 1.000000
# Shortness of Breath                     0.041946                 0.076269
# Loss of Appetite                        0.028756                 0.007372
# Fast Heart Rate                        -0.011706                 0.008566
# Brittle Nails                          -0.006593                 0.020300
# Weight Loss                             0.038231                -0.029918
# Reduced Wound Healing Capacity         -0.030232                -0.011778
#
#                                 Shortness of Breath  Loss of Appetite  \
# Age                                        0.023250          0.013343
# Night Blindness                            0.003348         -0.043568
# Dry Eyes                                  -0.037169          0.020217
# Bleeding Gums                             -0.042391         -0.004768
# Fatigue                                    0.043567          0.073300
# Tingling Sensation                        -0.002230         -0.005108
# Low Sun Exposure                           0.041946          0.028756
# Reduced Memory Capacity                    0.076269          0.007372
# Shortness of Breath                        1.000000         -0.042558
# Loss of Appetite                          -0.042558          1.000000
# Fast Heart Rate                            0.003956         -0.013823
# Brittle Nails                             -0.037750         -0.022338
# Weight Loss                               -0.008690         -0.016278
# Reduced Wound Healing Capacity            -0.000455         -0.026340
#
#                                 Fast Heart Rate  Brittle Nails  Weight Loss  \
# Age                                    0.016526      -0.006484    -0.018400
# Night Blindness                       -0.020808      -0.021148     0.055736
# Dry Eyes                               0.010777      -0.013621    -0.020193
# Bleeding Gums                         -0.018538       0.008157     0.051002
# Fatigue                                0.025259      -0.072948    -0.034606
# Tingling Sensation                     0.010352      -0.016089    -0.006738
# Low Sun Exposure                      -0.011706      -0.006593     0.038231
# Reduced Memory Capacity                0.008566       0.020300    -0.029918
# Shortness of Breath                    0.003956      -0.037750    -0.008690
# Loss of Appetite                      -0.013823      -0.022338    -0.016278
# Fast Heart Rate                        1.000000       0.006255     0.009215
# Brittle Nails                          0.006255       1.000000     0.024451
# Weight Loss                            0.009215       0.024451     1.000000
# Reduced Wound Healing Capacity         0.067986      -0.000331     0.034246
#
#                                 Reduced Wound Healing Capacity
# Age                                                   0.000324
# Night Blindness                                      -0.045829
# Dry Eyes                                              0.012291
# Bleeding Gums                                        -0.039730
# Fatigue                                              -0.025531
# Tingling Sensation                                    0.039747
# Low Sun Exposure                                     -0.030232
# Reduced Memory Capacity                              -0.011778
# Shortness of Breath                                  -0.000455
# Loss of Appetite                                     -0.026340
# Fast Heart Rate                                       0.067986
# Brittle Nails                                        -0.000331
# Weight Loss                                           0.034246
# Reduced Wound Healing Capacity                        1.000000

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler

ct2 = ColumnTransformer(transformers=[('onehot', OneHotEncoder(drop='first',sparse_output=False), ['Gender','Diet Type','Living Environment','Skin Condition'])], remainder='passthrough', sparse_threshold=0)

ct2
# Out:
# ColumnTransformer(remainder='passthrough', sparse_threshold=0,
#                   transformers=[('onehot',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['Gender', 'Diet Type', 'Living Environment',
#                                   'Skin Condition'])])

# %% [markdown]
# ## Data Splitting

# %%
from sklearn.model_selection import train_test_split

X = deficiency[['Age','Gender','Diet Type','Living Environment','Night Blindness','Dry Eyes','Bleeding Gums', 'Fatigue', 'Tingling Sensation',
                'Low Sun Exposure','Reduced Memory Capacity','Shortness of Breath','Loss of Appetite', 'Fast Heart Rate','Brittle Nails',
                'Weight Loss','Reduced Wound Healing Capacity','Skin Condition']]

le = LabelEncoder()
Y = le.fit_transform(deficiency['Predicted Deficiency'])

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=789)

X_train.shape, y_train.shape
# Out:
# ((799, 18), (799,))

# %%
X_test.shape, y_test.shape
# Out:
# ((200, 18), (200,))

# %% [markdown]
# ## Model Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import HistGradientBoostingRegressor
pipe = Pipeline([('ct', ct2), ('model', HistGradientBoostingRegressor(max_iter=1098, max_leaf_nodes=27, min_samples_leaf=1, l2_regularization=0.27))])

# %% [markdown]
# ## Pipeline Training

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough', sparse_threshold=0,
#                                    transformers=[('onehot',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['Gender', 'Diet Type',
#                                                    'Living Environment',
#                                                    'Skin Condition'])])),
#                 ('model',
#                  HistGradientBoostingRegressor(l2_regularization=0.27,
#                                                max_iter=1098, max_leaf_nodes=27,
#                                                min_samples_leaf=1))])

# %% [markdown]
# ## Pipeline Evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error as mse
y = pipe.predict(X)

print(f'Score: {pipe.score(X,Y)}')
print(f'MSE: {mse(Y, np.round(y,0))}')
# Out:
# Score: 0.8328392769278261
# MSE: 0.6796796796796797

# %% [markdown]
# ## Food Recommender

# %%
deficit = le.classes_
def food_recommender(obj):
    x = pd.DataFrame(obj)
    y = pipe.predict(x)
    deficiency = deficit[np.int64(np.round(y,0)[0])]
    print(f'Your deficiency: {deficiency}')
    if deficiency != 'No Deficiency':
        foods = nutritions.sort_values(by=deficiency,ascending=False,ignore_index=True).loc[:9,['Food','Category']]
        print(f'Foods Recommended: ')
        count = 1
        for i in foods.values:
            print(f'{count}. {i[0]} ({i[1]})')
            count += 1

# %% [markdown]
# #### Example - 1

# %%
obj = {'Age':[25],'Gender':['Male'],'Diet Type':['Non-Vegetarian'],'Living Environment':['Rural'],
       'Night Blindness':[1],'Dry Eyes':[0],'Bleeding Gums':[0],'Fatigue':[0],'Tingling Sensation':[1],
       'Low Sun Exposure':[1],'Reduced Memory Capacity':[1],'Shortness of Breath':[0],'Loss of Appetite':[0],
       'Fast Heart Rate':[0],'Brittle Nails':[0],'Weight Loss':[1],'Reduced Wound Healing Capacity':[1],'Skin Condition':['Normal']
      }

food_recommender(obj)
# Out:
# Your deficiency: Vitamin A
# Foods Recommended:
# 1. Cod liver oil (Seafood)
# 2. Paprika (Spices)
# 3. Cayenne pepper (Spices)
# 4. Pasilla peppers (Vegetables)
# 5. Beef Liver (Meat)
# 6. Chili powder spice (Spices)
# 7. Grape leaves (Greens)
# 8. Sweet potato chips (Meals, Entrees, and Side Dishes)
# 9. Poblano (Vegetables)
# 10. Sweet potato (Vegetables)

# %% [markdown]
# #### Example - 2

# %%
obj = {'Age':[60],'Gender':['Female'],'Diet Type':['Non-Vegetarian'],'Living Environment':['Rural'],
       'Night Blindness':[0],'Dry Eyes':[0],'Bleeding Gums':[0],'Fatigue':[0],'Tingling Sensation':[1],
       'Low Sun Exposure':[1],'Reduced Memory Capacity':[1],'Shortness of Breath':[0],'Loss of Appetite':[0],
       'Fast Heart Rate':[0],'Brittle Nails':[0],'Weight Loss':[0],'Reduced Wound Healing Capacity':[1],'Skin Condition':['Normal']
      }
food_recommender(obj)
# Out:
# Your deficiency: Vitamin D
# Foods Recommended:
# 1. Cod liver oil (Seafood)
# 2. Maitake mushrooms (Mushrooms)
# 3. Trout (Seafood)
# 4. Swordfish (Seafood)
# 5. Sockeye salmon (Seafood)
# 6. Smoked salmon (Seafood)
# 7. Steelhead trout (Seafood)
# 8. Sturgeon (Seafood)
# 9. Salmon (Seafood)
# 10. Fish oil (Oils and Sauces)

# %% [markdown]
# #### Ezample - 3

# %%
obj = {'Age':[45],'Gender':['Female'],'Diet Type':['Vegetarian'],'Living Environment':['Urban'],
       'Night Blindness':[0],'Dry Eyes':[0],'Bleeding Gums':[0],'Fatigue':[0],'Tingling Sensation':[1],
       'Low Sun Exposure':[1],'Reduced Memory Capacity':[0],'Shortness of Breath':[0],'Loss of Appetite':[1],
       'Fast Heart Rate':[0],'Brittle Nails':[0],'Weight Loss':[0],'Reduced Wound Healing Capacity':[1],'Skin Condition':['Normal']
      }
food_recommender(obj)
# Out:
# Your deficiency: Vitamin C
# Foods Recommended:
# 1. Acerola (Fruits)
# 2. Rose hip (Fruits)
# 3. Chili Pepper (Vegetables)
# 4. Guava (Fruits)
# 5. Thyme (Greens)
# 6. Cloudberry (Fruits)
# 7. Chili pepper (Vegetables)
# 8. Drumstick tree (Greens)
# 9. Parsley (Greens)
# 10. Dried parsely (Spices)
